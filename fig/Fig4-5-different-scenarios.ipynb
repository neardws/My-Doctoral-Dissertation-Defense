# %%
import matplotlib.pyplot as plt
import numpy as np
import brewer2mpl
bmap = brewer2mpl.get_map('Paired', 'qualitative', 10)
colors = bmap.mpl_colors

colors = colors[0: 10]

fig_title = ['(a)', '(b)', '(c)', '(d)']

labels = ['RA', 'D4PG', 'MAD4PG', 'MAMO']

markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 35
markersize = 25
plt.figure(figsize=(16, 12))            # 确定图像画布的大小
plt.rcParams['font.family'] = 'Times New Roman' # 设置字体
x_label = 'Traffic scenario'
#################################################################### #################################################################
# plt.subplot(2, 2, 1)                        # 将画布分为两列

# plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
# plt.ylabel('QPUC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
# # plt.title(fig_title[0], fontsize=font_size, y=-0.22)     # 图的title

# x_vals = [1, 2, 3]

# ra_cc = [184.43749030366965, 198.431242902245, 183.6974473632022302245]
# d3pg_cc = [264.28406767284963, 259.7012284316506, 254.4490214176701]
# madrl_cc = [184.57610413046152, 203.1538561578501, 197.580636017138]
# mamodrl_cc = [285.87346129514765, 281.14356385949003, 280.7012431205267]

# ra_cq = [228.8718349159325, 230.9602806317781, 224.1754653376596]
# d3pg_cq = [268.07206089765936, 263.5256663049404, 289.64478992025835]
# madrl_cq = [247.28689343201236, 251.36963368518687, 228.22932806042368]
# mamodrl_cq = [234.46016503428487, 253.4123682830202, 237.34738126883823]

# ra = [0, 0, 0]
# d3pg = [0, 0, 0]
# madrl = [0, 0, 0]
# mamo = [0, 0, 0]

# for i in range(3):
#     ra[i] = ra_cq[i] / (300 - ra_cc[i])
#     d3pg[i] =d3pg_cq[i] / (300 - d3pg_cc[i])
#     madrl[i] = madrl_cq[i] / (300 - madrl_cc[i])
#     mamo[i] = mamodrl_cq[i] / (300 - mamodrl_cc[i])

# new_x_index = ['Scenario 1', 'Scenario 2', 'Scenario 3']
# diff = 1
# x = np.arange(1, 4, 1)

# width = diff * 0.12
# small_width = diff * 0.03
# label_text_size = 35

# edgecolor = 'black'

# plt.grid()

# plt.bar(x - width - 5 * small_width, ra, width, label=labels[0], hatch="x", color=colors[0], edgecolor=edgecolor)
# plt.bar(x - width + 1 * small_width, d3pg, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=edgecolor)
# plt.bar(x + 3 * small_width, madrl, width, label=labels[2], hatch="/", color=colors[4], edgecolor=edgecolor)
# plt.bar(x + 9 * small_width, mamo, width, label=labels[3], hatch="+", color=colors[6], edgecolor=edgecolor)

# ra_improvement = 0
# d3pg_improvement = 0
# madrl_improvement = 0

# for i in range(3):
#     ra_improvement += (mamo[i] - ra[i]) / ra[i]
#     d3pg_improvement += (mamo[i] - d3pg[i]) / d3pg[i]
#     madrl_improvement += (mamo[i] - madrl[i]) / madrl[i]
    
# print(ra_improvement / 3)
# print(d3pg_improvement / 3)
# print(madrl_improvement / 3)

# ax = plt.gca()
# plt.xticks(x_vals, new_x_index, fontsize=font_size)

# plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
#################################################################### #################################################################
# plt.subplot(2, 2, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('PPUQ', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
# plt.title(fig_title[1], fontsize=font_size, y=-0.22)     # 图的title


ra_cc = [184.43749030366965, 198.431242902245, 183.6974473632022302245]
d3pg_cc = [264.28406767284963, 259.7012284316506, 254.4490214176701]
madrl_cc = [184.57610413046152, 203.1538561578501, 197.580636017138]
mamodrl_cc = [285.87346129514765, 281.14356385949003, 280.7012431205267]

ra_cq = [228.8718349159325, 230.9602806317781, 224.1754653376596]
d3pg_cq = [268.07206089765936, 263.5256663049404, 289.64478992025835]
madrl_cq = [247.28689343201236, 251.36963368518687, 228.22932806042368]
mamodrl_cq = [234.46016503428487, 253.4123682830202, 237.34738126883823]

ra = [0, 0, 0]
d3pg = [0, 0, 0]
madrl = [0, 0, 0]
mamo = [0, 0, 0]

for i in range(3):
    ra[i] = ra_cc[i] / ra_cq[i]
    d3pg[i] =d3pg_cc[i] / d3pg_cq[i]
    madrl[i] = madrl_cc[i] / madrl_cq[i]
    mamo[i] = mamodrl_cc[i] / mamodrl_cq[i]

plt.bar(x - width - 5 * small_width, ra, width, label=labels[0], hatch="x", color=colors[0], edgecolor=edgecolor)
plt.bar(x - width + 1 * small_width, d3pg, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=edgecolor)
plt.bar(x + 3 * small_width, madrl, width, label=labels[2], hatch="/", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mamo, width, label=labels[3], hatch="+", color=colors[6], edgecolor=edgecolor)

ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)

ra_improvement = 0
d3pg_improvement = 0
madrl_improvement = 0

for i in range(3):
    ra_improvement += (mamo[i] - ra[i]) / ra[i]
    d3pg_improvement += (mamo[i] - d3pg[i]) / d3pg[i]
    madrl_improvement += (mamo[i] - madrl[i]) / madrl[i]
    
print(ra_improvement / 3)
print(d3pg_improvement / 3)
print(madrl_improvement / 3)

plt.grid()
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

# #################################################################### #################################################################

# plt.subplot(2, 2, 3)
# plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
# plt.ylabel('ASC', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
# plt.title(fig_title[2], fontsize=font_size, y=-0.22)     # 图的title

# ra_sensing_cost = [0.4797440910810776, 0.4666399544866637, 0.4914108764738836]
# d4pg_sensing_cost  = [0.19384553485588918, 0.22649595641707226, 0.22852881493484145]
# mad4pg_sensing_cost  = [0.5083994920818374, 0.4924105378391942, 0.4842818475553884]
# mamo_sensing_cost = [0.0719285321728068, 0.131038247391626, 0.1162573482085939]

# plt.bar(x - width - 5 * small_width, ra_sensing_cost, width, label=labels[0], hatch="x", color=colors[0], edgecolor=edgecolor)
# plt.bar(x - width + 1 * small_width, d4pg_sensing_cost, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=edgecolor)
# plt.bar(x + 3 * small_width, mad4pg_sensing_cost, width, label=labels[2], hatch="/", color=colors[4], edgecolor=edgecolor)
# plt.bar(x + 9 * small_width, mamo_sensing_cost, width, label=labels[3], hatch="+", color=colors[6], edgecolor=edgecolor)

# ax = plt.gca()
# plt.xticks(x_vals, new_x_index, fontsize=font_size)

# plt.grid()

# # plt.ylim(0, 0.7)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# # 刻度值字体大小设置
# plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放


# #################################################################### #################################################################
# plt.subplot(2, 2, 4)                       # 将画布分为两列
# plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
# plt.ylabel('ATC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
# plt.title(fig_title[3], fontsize=font_size, y=-0.22)     # 图的title

# ra_transmission_cost = [0.3560973358755216, 0.2725189588279612, 0.3553365859756205]
# d4pg_transmission_cost  = [0.08162394951287599, 0.08289165611487173, 0.10731267325124005]
# mad4pg_transmission_cost  = [0.2849814583461343, 0.186418438623166, 0.2199767411906842]
# mamo_transmission_cost = [0.0457926237009626, 0.03968007878976352, 0.0445656257870168]

# plt.bar(x - width - 5 * small_width, ra_transmission_cost, width, label=labels[0], hatch="x", color=colors[0], edgecolor=edgecolor)
# plt.bar(x - width + 1 * small_width, d4pg_transmission_cost, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=edgecolor)
# plt.bar(x + 3 * small_width, mad4pg_transmission_cost, width, label=labels[2], hatch="/", color=colors[4], edgecolor=edgecolor)
# plt.bar(x + 9 * small_width, mamo_transmission_cost, width, label=labels[3], hatch="+", color=colors[6], edgecolor=edgecolor)

# ax = plt.gca()
# plt.xticks(x_vals, new_x_index, fontsize=font_size)

# plt.grid()
# # plt.ylim(0, 1.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# # 刻度值字体大小设置
# plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

# plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig4-5-different-scenarios2.pdf", bbox_inches='tight')
plt.show()
# Out:
# 0.4158645104428818
# 0.2362586394759829
# 0.45746525243316655
